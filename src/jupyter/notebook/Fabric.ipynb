// %% [markdown]
// ## Fabric Gateway Client
// This notebook interacts with our Hyperledger Fabric blockchain, using our JavaScript module, as to simulate a Jupyter extension (i.e. the frontend).
// Note that the code is executed on the backend (using a Jupyter kernel), whereas a Jupyter extension would run this code on the frontend (i.e. the web browser). This has two major consequences: 1. The traffic between this client and Fabric will occur via the backend (i.e. IP routing, DNS, TLS, etc. will take place within that context). 2. The user's private key is generated and stored on the backend (rather than never leaving the web browser's memory). As long as JupyterLab is executed on the *same* system (e.g. your laptop) this does not matter (both the backend and frontend are running on the same host), but be aware when tunneling JupyterLab.

// %% [markdown]
// ### Prerequisites
// We use 'IJavascript' to run JavaScript from JupyterLab (as a kernel / on the JupyterLab backend. We also install the node version specified by Fabric's documentation (v14).

// %%
!mamba install --yes make cxx-compiler nodejs=14.18.3
// Out:
//                   __    __    __    __
//                  /  \  /  \  /  \  /  \
//                 /    \/    \/    \/    \
// ███████████████/  /██/  /██/  /██/  /████████████████████████
//               /  / \   / \   / \   / \  \____
//              /  /   \_/   \_/   \_/   \    o \__,
//             / _/                       \_____/  `
//             |/
//         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
//         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
//         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
//         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
//         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
//         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
//
//         mamba (0.22.0) supported by @QuantStack
//
//         GitHub:  https://github.com/mamba-org/mamba
//         Twitter: https://twitter.com/QuantStack
//
// █████████████████████████████████████████████████████████████
//
//
// Looking for: ['make', 'cxx-compiler', 'nodejs=14.18.3']
//
// [+] 0.0s
// [+] 0.1s
// conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
// conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
// conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
// conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
// conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
// conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━  15.0 B /  ??.?MB @  58.0 B/s  0.3s[+] 0.4s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━ 566.3kB /  ??.?MB @   1.6MB/s  0.4s
// conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━ 525.7kB /  ??.?MB @   1.5MB/s  0.4s[+] 0.5s
// conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   1.1MB /  ??.?MB @   2.3MB/s  0.5s
// conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━   1.0MB /  ??.?MB @   2.3MB/s  0.5s[+] 0.6s
// conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   1.7MB /  ??.?MB @   3.0MB/s  0.6s
// conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   1.4MB /  ??.?MB @   2.5MB/s  0.6s[+] 0.7s
// conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   2.3MB /  ??.?MB @   3.4MB/s  0.7s
// conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   1.5MB /  ??.?MB @   2.3MB/s  0.7s[+] 0.8s
// conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   2.9MB /  ??.?MB @   3.8MB/s  0.8s
// conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   1.6MB /  ??.?MB @   2.1MB/s  0.8s[+] 0.9s
// conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   3.4MB /  ??.?MB @   3.9MB/s  0.9s
// conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━   1.7MB /  ??.?MB @   2.0MB/s  0.9s[+] 1.0s
// conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   4.0MB /  ??.?MB @   4.1MB/s  1.0s
// conda-forge/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━   1.9MB /  ??.?MB @   1.9MB/s  1.0s[+] 1.1s
// conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   4.5MB /  ??.?MB @   4.3MB/s  1.1s
// conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   2.0MB /  ??.?MB @   1.9MB/s  1.1s[+] 1.2s
// conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   5.1MB /  ??.?MB @   4.4MB/s  1.2s
// conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   2.3MB /  ??.?MB @   2.0MB/s  1.2s[+] 1.3s
// conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   5.7MB /  ??.?MB @   4.5MB/s  1.3s
// conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   2.8MB /  ??.?MB @   2.2MB/s  1.3s[+] 1.4s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   6.3MB /  ??.?MB @   4.6MB/s  1.4s
// conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   3.3MB /  ??.?MB @   2.4MB/s  1.4s[+] 1.5s
// conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   6.9MB /  ??.?MB @   4.7MB/s  1.5s
// conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━   3.8MB /  ??.?MB @   2.6MB/s  1.5s[+] 1.6s
// conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   7.4MB /  ??.?MB @   4.7MB/s  1.6s
// conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   4.3MB /  ??.?MB @   2.8MB/s  1.6s[+] 1.7s
// conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.0MB /  ??.?MB @   4.8MB/s  1.7s
// conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   4.8MB /  ??.?MB @   2.9MB/s  1.7s[+] 1.8s
// conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   8.6MB /  ??.?MB @   4.9MB/s  1.8s
// conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   5.3MB /  ??.?MB @   3.0MB/s  1.8s[+] 1.9s
// conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   9.2MB /  ??.?MB @   4.9MB/s  1.9s
// conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━   5.8MB /  ??.?MB @   3.1MB/s  1.9s[+] 2.0s
// conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   9.8MB /  ??.?MB @   5.0MB/s  2.0s
// conda-forge/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━   6.4MB /  ??.?MB @   3.2MB/s  2.0s[+] 2.1s
// conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  10.3MB /  ??.?MB @   5.0MB/s  2.1s
// conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   6.8MB /  ??.?MB @   3.3MB/s  2.1s[+] 2.2s
// conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  11.0MB /  ??.?MB @   5.1MB/s  2.2s
// conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   7.3MB /  ??.?MB @   3.3MB/s  2.2s[+] 2.3s
// conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  11.5MB /  ??.?MB @   5.1MB/s  2.3s
// conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   7.7MB /  ??.?MB @   3.4MB/s  2.3s[+] 2.4s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━  12.1MB @   5.1MB/s             2.4s
// conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━   8.3MB @   3.5MB/s Finalizing  2.4s[+] 2.5s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━  12.1MB @   5.1MB/s             2.5s
// conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━   8.3MB @   3.5MB/s Finalizing  2.5s[+] 2.6s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━  12.1MB @   5.1MB/s             2.6s
// conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━   8.3MB @   3.5MB/s Finalizing  2.6s[+] 2.7s
// conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━  12.1MB @   5.1MB/s             2.7s
// conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━   8.3MB @   3.5MB/s Finalizing  2.7sconda-forge/noarch                                 @   3.5MB/s  2.8s
// [+] 2.8s
// conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  12.2MB /  ??.?MB @   4.4MB/s  2.8s[+] 2.9s
// conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  14.3MB /  ??.?MB @   5.0MB/s  2.9s[+] 3.0s
// conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  15.2MB /  ??.?MB @   5.1MB/s  3.0s[+] 3.1s
// conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  15.8MB /  ??.?MB @   5.1MB/s  3.1s[+] 3.2s
// conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  16.3MB /  ??.?MB @   5.1MB/s  3.2s[+] 3.3s
// conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  16.8MB /  ??.?MB @   5.1MB/s  3.3s[+] 3.4s
// conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  17.4MB /  ??.?MB @   5.1MB/s  3.4s[+] 3.5s
// conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  17.9MB /  ??.?MB @   5.1MB/s  3.5s[+] 3.6s
// conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  18.3MB /  ??.?MB @   5.1MB/s  3.6s[+] 3.7s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━  18.9MB /  ??.?MB @   5.1MB/s  3.7s[+] 3.8s
// conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  19.4MB /  ??.?MB @   5.1MB/s  3.8s[+] 3.9s
// conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  20.0MB /  ??.?MB @   5.1MB/s  3.9s[+] 4.0s
// conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  20.6MB /  ??.?MB @   5.1MB/s  4.0s[+] 4.1s
// conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  21.1MB /  ??.?MB @   5.2MB/s  4.1s[+] 4.2s
// conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  21.7MB /  ??.?MB @   5.2MB/s  4.2s[+] 4.3s
// conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  22.3MB /  ??.?MB @   5.2MB/s  4.3s[+] 4.4s
// conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  22.8MB /  ??.?MB @   5.2MB/s  4.4s[+] 4.5s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  4.5s[+] 4.6s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  4.6s[+] 4.7s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  4.7s[+] 4.8s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  4.8s[+] 4.9s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  4.9s[+] 5.0s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  5.0s[+] 5.1s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  5.1s[+] 5.2s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  5.2s[+] 5.3s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  5.3s[+] 5.4s
// conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  23.2MB @   5.2MB/s Finalizing  5.4s[+] 5.5s
// [+] 5.6s
// [+] 5.7s
// [+] 5.8s
// [+] 5.9s
// conda-forge/linux-64                               @   5.2MB/s  5.4s
//
// Pinned packages:
//   - python 3.9.*
//   - python 3.9.10
//
//
// Transaction
//
//   Prefix: /opt/conda
//
//   Updating specs:
//
//    - make
//    - cxx-compiler
//    - nodejs=14.18.3
//    - ca-certificates
//    - certifi
//    - openssl
//
//
//   Package                         Version  Build              Channel                   Size
// ──────────────────────────────────────────────────────────────────────────────────────────────
//   Install:
// ──────────────────────────────────────────────────────────────────────────────────────────────
//
//   + binutils                       2.36.1  hdd6e379_2         conda-forge/linux-64      27kB
//   + binutils_impl_linux-64         2.36.1  h193b22a_2         conda-forge/linux-64      11MB
//   + binutils_linux-64                2.36  hf3e587d_10        conda-forge/linux-64      25kB
//   + c-compiler                      1.4.2  h166bdaf_0         conda-forge/linux-64       5kB
//   + cxx-compiler                    1.4.2  h924138e_0         conda-forge/linux-64       5kB
//   + gcc                            10.3.0  he2824d0_10        conda-forge/linux-64      25kB
//   + gcc_impl_linux-64              10.3.0  hf2f2afa_16        conda-forge/linux-64      49MB
//   + gcc_linux-64                   10.3.0  hc39de41_10        conda-forge/linux-64      25kB
//   + gxx                            10.3.0  he2824d0_10        conda-forge/linux-64      24kB
//   + gxx_impl_linux-64              10.3.0  hf2f2afa_16        conda-forge/linux-64      12MB
//   + gxx_linux-64                   10.3.0  h2593f52_10        conda-forge/linux-64      25kB
//   + kernel-headers_linux-64        2.6.32  he073ed8_15        conda-forge/noarch       724kB
//   + libgcc-devel_linux-64          10.3.0  he6cfe16_16        conda-forge/linux-64       4MB
//   + libsanitizer                   10.3.0  h26c7422_16        conda-forge/linux-64       6MB
//   + libstdcxx-devel_linux-64       10.3.0  he6cfe16_16        conda-forge/linux-64      10MB
//   + make                              4.3  hd18ef5c_1         conda-forge/linux-64     519kB
//   + sysroot_linux-64                 2.12  he073ed8_15        conda-forge/noarch        33MB
//
//   Change:
// ──────────────────────────────────────────────────────────────────────────────────────────────
//
//   - configurable-http-proxy         4.5.1  node17_h7e777a6_1  installed
//   + configurable-http-proxy         4.5.1  node14_h5556789_1  conda-forge/linux-64       2MB
//
//   Upgrade:
// ──────────────────────────────────────────────────────────────────────────────────────────────
//
//   - ca-certificates             2021.10.8  ha878542_0         installed
//   + ca-certificates           2022.5.18.1  ha878542_0         conda-forge/linux-64     148kB
//   - certifi                     2021.10.8  py39hf3d152e_1     installed
//   + certifi                   2022.5.18.1  py39hf3d152e_0     conda-forge/linux-64     154kB
//   - icu                              69.1  h9c3ff4c_0         installed
//   + icu                              70.1  h27087fc_0         conda-forge/linux-64      14MB
//   - libxml2                        2.9.12  h885dcf4_1         installed
//   + libxml2                        2.9.14  h22db469_0         conda-forge/linux-64     789kB
//   - openssl                        1.1.1l  h7f98852_0         installed
//   + openssl                        1.1.1o  h166bdaf_0         conda-forge/linux-64       2MB
//
//   Downgrade:
// ──────────────────────────────────────────────────────────────────────────────────────────────
//
//   - nodejs                         17.4.0  h8ca31f7_0         installed
//   + nodejs                        14.18.3  h96d913c_3         conda-forge/linux-64      16MB
//
//   Summary:
//
//   Install: 17 packages
//   Change: 1 packages
//   Upgrade: 5 packages
//   Downgrade: 1 packages
//
//   Total download: 161MB
//
// ──────────────────────────────────────────────────────────────────────────────────────────────
//
// [+] 0.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
// Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
// Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   0.0 B ca-certificates            0.0s
// Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.2s
// Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   0.0 B ca-certificates            0.1s
// Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.3s
// Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   0.0 B ca-certificates            0.2s
// Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sca-certificates                                    147.8kB @ 469.5kB/s  0.3s
// certifi                                            153.7kB @ 454.7kB/s  0.3s
// make                                               518.9kB @   1.5MB/s  0.3s
// binutils_linux-64                                   24.6kB @  63.9kB/s  0.0s
// [+] 0.4s
// Downloading  (5) ━━━━╸━━━━━━━━━━━━━━━━━━   1.8MB binutils_impl_linux-64     0.3s
// Extracting   (4) ━━━━━━━━━╸━━━━━━━━━━━━━       0 binutils_linux-64          0.0sgcc_linux-64                                        25.2kB @  60.0kB/s  0.0s
// [+] 0.5s
// Downloading  (5) ━━━━╸━━━━━━━━━━━━━━━━━━   3.4MB binutils_impl_linux-64     0.4s
// Extracting   (5) ━━━━━━━━━━╸━━━━━━━━━━━━       0 binutils_linux-64          0.1sconfigurable-http-proxy                              1.8MB @   3.4MB/s  0.2s
// c-compiler                                           5.1kB @   9.0kB/s  0.1s
// [+] 0.6s
// Downloading  (5) ╸━━━━━━━━╸━━━━━━━━━━━━━  11.9MB binutils_impl_linux-64     0.5s
// Extracting   (7) ━━━━━━━━━━━╸━━━━━━━━━━━       0 binutils_linux-64          0.2s[+] 0.7s
// Downloading  (5) ━╸━━━━━━━━╸━━━━━━━━━━━━  20.7MB binutils_impl_linux-64     0.6s
// Extracting   (7) ━━━━━━━━━━━━╸━━━━━━━━━━       0 binutils_linux-64          0.3s[+] 0.8s
// Downloading  (5) ━━╸━━━━━━━╸━━━━━━━━━━━━  24.1MB icu                        0.7s
// Extracting   (7) ━━━━━━━━━━━━━╸━━━━━━━━━       0 c-compiler                 0.4s[+] 0.9s
// Downloading  (5) ━━╸━━━━━━━━╸━━━━━━━━━━━  26.6MB icu                        0.8s
// Extracting   (7) ━━━━━━━━━━━━━━╸━━━━━━━━       0 c-compiler                 0.5s[+] 1.0s
// Downloading  (5) ━━╸━━━━━━━━╸━━━━━━━━━━━  28.7MB icu                        0.9s
// Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━       0 c-compiler                 0.6s[+] 1.1s
// Downloading  (5) ━━━╸━━━━━━━━╸━━━━━━━━━━  34.0MB icu                        1.0s
// Extracting   (7) ╸━━━━━━━━━━━━━━━╸━━━━━━       0 c-compiler                 0.7s[+] 1.2s
// Downloading  (5) ━━━━╸━━━━━━━╸━━━━━━━━━━  38.5MB libsanitizer               1.1s
// Extracting   (7) ━━╸━━━━━━━━━━━━━━━╸━━━━       0 ca-certificates            0.8slibsanitizer                                         6.2MB @   4.9MB/s  0.7s
// [+] 1.3s
// Downloading  (5) ━━━━╸━━━━━━━━╸━━━━━━━━━  43.2MB binutils                   1.2s
// Extracting   (8) ━━━╸━━━━━━━━━━━━━━━╸━━━       0 ca-certificates            0.9slibstdcxx-devel_linux-64                            10.0MB @   7.5MB/s  1.3s
// [+] 1.4s
// Downloading  (5) ━━━━━╸━━━━━━━━━╸━━━━━━━  48.1MB binutils                   1.3s
// Extracting   (9) ━━━━╸━━━━━━━━━━━━━━━╸━━       0 ca-certificates            1.0sbinutils                                            27.5kB @  19.4kB/s  0.1s
// binutils_impl_linux-64                              10.9MB @   7.7MB/s  1.1s
// [+] 1.5s
// Downloading  (5) ━━━━━━╸━━━━━━━━━━╸━━━━━  53.4MB cxx-compiler               1.4s
// Extracting  (11) ━━━━━╸━━━━━━━━━━━━━━━╸━       0 ca-certificates            1.1scxx-compiler                                         5.1kB @   3.3kB/s  0.1s
// openssl                                              2.2MB @   1.4MB/s  0.1s
// icu                                                 14.2MB @   9.0MB/s  1.6s
// gxx_linux-64                                        24.9kB @  15.7kB/s  0.0s
// [+] 1.6s
// Downloading  (5) ━━━━━━━╸━━━━━━━━━━━━━━━  61.4MB gcc_impl_linux-64          1.5s
// Extracting  (14) ━━━━━━╸━━━━━━━━━━━━━━━━       0 certifi                    1.2skernel-headers_linux-64                            723.9kB @ 438.8kB/s  0.1s
// [+] 1.7s
// Downloading  (5) ━━━━━━━━╸━━━━━━━━━━━━━━  68.5MB gcc_impl_linux-64          1.6s
// Extracting  (16) ━━━━━━━╸━━━━━━━━━━━━━━━       0 certifi                    1.3slibgcc-devel_linux-64                                3.5MB @   2.0MB/s  0.2s
// [+] 1.8s
// Downloading  (5) ━━━━━━━━━━╸━━━━━━━━━━━━  78.2MB gcc_impl_linux-64          1.7s
// Extracting  (17) ━━━━━━━━╸━━━━━━━━━━━━━━       0 certifi                    1.4sgxx                                                 24.3kB @  13.3kB/s  0.0s
// nodejs                                              16.1MB @   8.9MB/s  1.2s
// gxx_impl_linux-64                                   12.0MB @   6.4MB/s  0.5s
// libxml2                                            788.6kB @ 419.6kB/s  0.1s
// [+] 1.9s
// Downloading  (3) ━━━━━━━━━━━╸━━━━━━━━━━━  91.5MB gcc_impl_linux-64          1.8s
// Extracting  (21) ━━━━━━━━━╸━━━━━━━━━━━━━       0 certifi                    1.5sgcc                                                 24.8kB @  12.8kB/s  0.1s
// [+] 2.0s
// Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━  98.5MB sysroot_linux-64           1.9s
// Extracting  (22) ━━━━━━━━━━╸━━━━━━━━━━━━       0 configurable-http-proxy    1.6s[+] 2.1s
// Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━  98.5MB sysroot_linux-64           2.0s
// Extracting  (22) ━━━━━━━━━━━╸━━━━━━━━━━━       0 configurable-http-proxy    1.7s[+] 2.2s
// Downloading  (2) ━━━━━━━━━━━━━╸━━━━━━━━━ 104.7MB sysroot_linux-64           2.1s
// Extracting  (17) ━━━╸━━━━━━━━━━━━━━━━━╸━       5 configurable-http-proxy    1.8s[+] 2.3s
// Downloading  (2) ━━━━━━━━━━━━━━╸━━━━━━━━ 110.4MB sysroot_linux-64           2.2s
// Extracting  (16) ━━━━╸━━━━━━━━━━━━━━━━╸━       6 configurable-http-proxy    1.9s[+] 2.4s
// Downloading  (2) ━━━━━━━━━━━━━━━╸━━━━━━━ 114.1MB gcc_impl_linux-64          2.3s
// Extracting  (16) ━━━━╸━━━━━━━━━━━━━━━━╸━       6 cxx-compiler               2.0ssysroot_linux-64                                    32.9MB @  13.3MB/s  0.8s
// [+] 2.5s
// Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 123.1MB gcc_impl_linux-64          2.4s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 cxx-compiler               2.1s[+] 2.6s
// Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 123.7MB gcc_impl_linux-64          2.5s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 cxx-compiler               2.2s[+] 2.7s
// Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 124.4MB gcc_impl_linux-64          2.6s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 cxx-compiler               2.3s[+] 2.8s
// Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 125.1MB gcc_impl_linux-64          2.7s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gcc                        2.4s[+] 2.9s
// Downloading  (1) ━━━━━━━━━━━━━━━━╸━━━━━━ 126.0MB gcc_impl_linux-64          2.8s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gcc                        2.5s[+] 3.0s
// Downloading  (1) ━━━━━━━━━━━━━━━━━╸━━━━━ 130.8MB gcc_impl_linux-64          2.9s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gcc                        2.6s[+] 3.1s
// Downloading  (1) ━━━━━━━━━━━━━━━━━━╸━━━━ 136.5MB gcc_impl_linux-64          3.0s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gcc                        2.7s[+] 3.2s
// Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━ 141.6MB gcc_impl_linux-64          3.1s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gxx                        2.8s[+] 3.3s
// Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━ 145.6MB gcc_impl_linux-64          3.2s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gxx                        2.9s[+] 3.4s
// Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━╸━ 155.1MB gcc_impl_linux-64          3.3s
// Extracting  (17) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gxx                        3.0sgcc_impl_linux-64                                   48.9MB @  14.2MB/s  1.9s
// [+] 3.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (18) ━━━━╸━━━━━━━━━━━━━━━━━━       6 gxx                        3.1s[+] 3.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (17) ━━━━━╸━━━━━━━━━━━━━━━━━       7 gxx_impl_linux-64          3.2s[+] 3.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (16) ━━━━━━╸━━━━━━━━━━━━━━━━       8 gxx_impl_linux-64          3.3s[+] 3.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (16) ━━━━━━╸━━━━━━━━━━━━━━━━       8 gxx_impl_linux-64          3.4s[+] 3.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (14) ━━━━━━━━╸━━━━━━━━━━━━━━      10 gxx_impl_linux-64          3.5s[+] 4.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (13) ━━━━━━━━━╸━━━━━━━━━━━━━      11 icu                        3.6s[+] 4.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (13) ━━━━━━━━━╸━━━━━━━━━━━━━      11 icu                        3.7s[+] 4.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (13) ━━━━━━━━━╸━━━━━━━━━━━━━      11 icu                        3.8s[+] 4.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (13) ━━━━━━━━━╸━━━━━━━━━━━━━      11 icu                        3.9s[+] 4.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (13) ━━━━━━━━━╸━━━━━━━━━━━━━      11 libgcc-devel_linux-64      4.0s[+] 4.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libgcc-devel_linux-64      4.1s[+] 4.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libgcc-devel_linux-64      4.2s[+] 4.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libgcc-devel_linux-64      4.3s[+] 4.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libsanitizer               4.4s[+] 4.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libsanitizer               4.5s[+] 5.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libsanitizer               4.6s[+] 5.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (12) ━━━━━━━━━━╸━━━━━━━━━━━━      12 libsanitizer               4.7s[+] 5.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 libstdcxx-devel_linux-64   4.8s[+] 5.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 libstdcxx-devel_linux-64   4.9s[+] 5.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 libstdcxx-devel_linux-64   5.0s[+] 5.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 libstdcxx-devel_linux-64   5.1s[+] 5.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 nodejs                     5.2s[+] 5.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 nodejs                     5.3s[+] 5.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 nodejs                     5.4s[+] 5.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (11) ━━━━━━━━━━━╸━━━━━━━━━━━      13 nodejs                     5.5s[+] 6.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 sysroot_linux-64           5.6s[+] 6.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 sysroot_linux-64           5.7s[+] 6.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 sysroot_linux-64           5.8s[+] 6.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 sysroot_linux-64           5.9s[+] 6.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils                   6.0s[+] 6.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils                   6.1s[+] 6.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils                   6.2s[+] 6.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils                   6.3s[+] 6.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils_impl_linux-64     6.4s[+] 6.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils_impl_linux-64     6.5s[+] 7.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils_impl_linux-64     6.6s[+] 7.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 binutils_impl_linux-64     6.7s[+] 7.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 cxx-compiler               6.8s[+] 7.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 cxx-compiler               6.9s[+] 7.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 cxx-compiler               7.0s[+] 7.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 cxx-compiler               7.1s[+] 7.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 gcc_impl_linux-64          7.2s[+] 7.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting  (10) ━━━━━━━━━━━━╸━━━━━━━━━━      14 gcc_impl_linux-64          7.3s[+] 7.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 gcc_impl_linux-64          7.4s[+] 7.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 gcc_impl_linux-64          7.5s[+] 8.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 icu                        7.6s[+] 8.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 icu                        7.7s[+] 8.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 icu                        7.8s[+] 8.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 icu                        7.9s[+] 8.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 libsanitizer               8.0s[+] 8.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 libsanitizer               8.1s[+] 8.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 libsanitizer               8.2s[+] 8.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (9) ━━━━━━━━━━━━━╸━━━━━━━━━      15 libsanitizer               8.3s[+] 8.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 libstdcxx-devel_linux-64   8.4s[+] 8.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 libstdcxx-devel_linux-64   8.5s[+] 9.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 libstdcxx-devel_linux-64   8.6s[+] 9.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 libstdcxx-devel_linux-64   8.7s[+] 9.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 nodejs                     8.8s[+] 9.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 nodejs                     8.9s[+] 9.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 nodejs                     9.0s[+] 9.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 nodejs                     9.1s[+] 9.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 sysroot_linux-64           9.2s[+] 9.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 sysroot_linux-64           9.3s[+] 9.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 sysroot_linux-64           9.4s[+] 9.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 sysroot_linux-64           9.5s[+] 10.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 binutils                   9.6s[+] 10.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 binutils                   9.7s[+] 10.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 binutils                   9.8s[+] 10.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 binutils                   9.9s[+] 10.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 cxx-compiler              10.0s[+] 10.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (8) ━━━━━━━━━━━━━━╸━━━━━━━━      16 cxx-compiler              10.1s[+] 10.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━      17 cxx-compiler              10.2s[+] 10.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━      17 cxx-compiler              10.3s[+] 10.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━      17 gcc_impl_linux-64         10.4s[+] 10.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (7) ━━━━━━━━━━━━━━━╸━━━━━━━      17 gcc_impl_linux-64         10.5s[+] 11.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (6) ━━━━━━━━━━━━━━━━╸━━━━━━      18 gcc_impl_linux-64         10.6s[+] 11.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (5) ━━━━━━━━━━━━━━━━━╸━━━━━      19 gcc_impl_linux-64         10.7s[+] 11.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (5) ━━━━━━━━━━━━━━━━━╸━━━━━      19 nodejs                    10.8s[+] 11.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (5) ━━━━━━━━━━━━━━━━━╸━━━━━      19 nodejs                    10.9s[+] 11.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (5) ━━━━━━━━━━━━━━━━━╸━━━━━      19 nodejs                    11.0s[+] 11.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (4) ━━━━━━━━━━━━━━━━━━╸━━━━      20 nodejs                    11.1s[+] 11.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (4) ━━━━━━━━━━━━━━━━━━╸━━━━      20 sysroot_linux-64          11.2s[+] 11.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          11.3s[+] 11.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          11.4s[+] 11.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          11.5s[+] 12.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         11.6s[+] 12.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         11.7s[+] 12.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         11.8s[+] 12.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         11.9s[+] 12.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    12.0s[+] 12.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    12.1s[+] 12.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    12.2s[+] 12.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    12.3s[+] 12.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          12.4s[+] 12.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          12.5s[+] 13.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          12.6s[+] 13.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          12.7s[+] 13.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         12.8s[+] 13.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         12.9s[+] 13.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         13.0s[+] 13.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 gcc_impl_linux-64         13.1s[+] 13.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    13.2s[+] 13.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    13.3s[+] 13.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    13.4s[+] 13.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 nodejs                    13.5s[+] 14.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (3) ━━━━━━━━━━━━━━━━━━━╸━━━      21 sysroot_linux-64          13.6s[+] 14.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 gcc_impl_linux-64         13.7s[+] 14.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 gcc_impl_linux-64         13.8s[+] 14.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 gcc_impl_linux-64         13.9s[+] 14.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 gcc_impl_linux-64         14.0s[+] 14.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 nodejs                    14.1s[+] 14.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 nodejs                    14.2s[+] 14.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 nodejs                    14.3s[+] 14.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (2) ━━━━━━━━━━━━━━━━━━━━╸━━      22 nodejs                    14.4s[+] 14.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         14.5s[+] 15.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         14.6s[+] 15.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         14.7s[+] 15.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         14.8s[+] 15.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         14.9s[+] 15.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         15.0s[+] 15.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         15.1s[+] 15.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         15.2s[+] 15.7s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         15.3s[+] 15.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         15.4s[+] 15.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.3s[+] 16.8s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.4s[+] 16.9s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.5s[+] 17.0s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.6s[+] 17.1s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.7s[+] 17.2s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.8s[+] 17.3s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         16.9s[+] 17.4s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         17.0s[+] 17.5s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         17.1s[+] 17.6s
// Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 161.5MB                            3.4s
// Extracting   (1) ━━━━━━━━━━━━━━━━━━━━━╸━      23 gcc_impl_linux-64         17.2sPreparing transaction: done
// Verifying transaction: done
// Executing transaction: done

// %%
!npm install -g ijavascript
!ijsinstall
// Out:
// npm WARN deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
// /opt/conda/bin/ijs -> /opt/conda/lib/node_modules/ijavascript/bin/ijavascript.js.3.0 is installed into aKmK
// /opt/conda/bin/ijsinstall -> /opt/conda/lib/node_modules/ijavascript/bin/ijsinstall.js
// /opt/conda/bin/ijsconsole -> /opt/conda/lib/node_modules/ijavascript/bin/ijsconsole.js
// /opt/conda/bin/ijskernel -> /opt/conda/lib/node_modules/ijavascript/lib/kernel.js
// /opt/conda/bin/ijsnotebook -> /opt/conda/lib/node_modules/ijavascript/bin/ijsnotebook.js
//
// > zeromq@5.2.8 install /opt/conda/lib/node_modules/ijavascript/node_modules/zeromq
// > node-gyp-build || npm run build:libzmq
//
// + ijavascript@5.2.1
// added 8 packages from 31 contributors in 6.903s

// %% [markdown]
// #### Admin tasks
// The organization's (Fabric and IPFS) administrator has to register a user and provision the IPFS network configuration.

// %% [markdown]
// **User registration**
// The Fabric CA admin registers a user (on the Docker host):

// %% [raw]
// docker exec -it ca-client.fabric.localhost ./registerUser.js --profile ../connection-profiles/connection-profile-orga.yaml --org orgA --user janssen

// %% [raw]
//  --- Fabric CA Client Application ---
// Existing wallet found at "./wallet"
// Registering user "janssen" in organization "orgA"
// An identity for the CA admin user "admin" of organization "orgA" does not exists in the wallet
// Enrolling CA admin user "admin" of organization "orgA"
// CA admin user password? adminpw
// Successfully enrolled the CA admin user "admin" of organization "orgA"
// Successfully imported identity of CA admin user "admin" of organization "orgA" into the wallet
// Successfully registered user "janssen" in organization "orgA"
// Secret of user "janssen": "jwSfmSTyalJE"
// ***SECURITY NOTE***: The secret is normally not visible to the CA admin (i.e. the secret is *only* send to the user)!

// %% [markdown]
// **Network provisioning**
// The organization's Fabric admin upload the IPFS private network configuration to the Fabric blockchain (on the Docker host).

// %% [raw]
// docker exec -it

// %% [markdown]
// ### Node.js module setup

// %% [raw]
// On the Docker host:
// cd ../src/jupyter/fabric-gw-client
// ./build.sh
// cp dist/*.tgz to the work directory of this Jupyterlab instance (cp dist/*.tgz ../notebook/)

// %%
!npm install --only=prod ./*.tgz
// Out:
// npm WARN deprecated querystring@0.2.0: The querystring API is considered Legacy. new code should use the URLSearchParams API instead.
//         ......] \ build:yargs: sill linkStuff yargs@16.2.0 has /home/jovyam0m
// > pkcs11js@1.3.0 install /home/jovyan/work/notebook/node_modules/pkcs11js
// > node-gyp rebuild
//
// make: Entering directory '/home/jovyan/work/notebook/node_modules/pkcs11js/build'
//   CXX(target) Release/obj.target/pkcs11/src/main.o
// In file included from ../../nan/nan.h:58,
//                  from ../src/main.cpp:1:
// /home/jovyan/.cache/node-gyp/14.18.3/include/node/node.h:787:7: warning: cast between incompatible function types from 'void (*)(Nan::ADDON_REGISTER_FUNCTION_ARGS_TYPE)' {aka 'void (*)(v8::Local<v8::Object>)'} to 'node::addon_register_func' {aka 'void (*)(v8::Local<v8::Object>, v8::Local<v8::Value>, void*)'} [-Wcast-function-type]
//   787 |       (node::addon_register_func) (regfunc),                          \
//       |       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/jovyan/.cache/node-gyp/14.18.3/include/node/node.h:821:3: note: in expansion of macro 'NODE_MODULE_X'
//   821 |   NODE_MODULE_X(modname, regfunc, NULL, 0)  // NOLINT (readability/null_usage)
//       |   ^~~~~~~~~~~~~
// ../src/main.cpp:27:1: note: in expansion of macro 'NODE_MODULE'
//    27 | NODE_MODULE(pkcs11, init)
//       | ^~~~~~~~~~~
//   CXX(target) Release/obj.target/pkcs11/src/dl.o
//   CXX(target) Release/obj.target/pkcs11/src/const.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/error.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/v8_convert.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/template.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/mech.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/param.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/param_aes.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/param_rsa.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/param_ecdh.o
//   CXX(target) Release/obj.target/pkcs11/src/pkcs11/pkcs11.o
//   CXX(target) Release/obj.target/pkcs11/src/async.o
//   CXX(target) Release/obj.target/pkcs11/src/node.o
//   SOLINK_MODULE(target) Release/obj.target/pkcs11.node
//   COPY Release/pkcs11.node
// make: Leaving directory '/home/jovyan/work/notebook/node_modules/pkcs11js/build'
//
// > protobufjs@6.11.3 postinstall /home/jovyan/work/notebook/node_modules/protobufjs
// > node scripts/postinstall
//
// npm WARN saveError ENOENT: no such file or directory, open '/home/jovyan/work/notebook/package.json'
// npm notice created a lockfile as package-lock.json. You should commit this file.
// npm WARN notsup Unsupported engine for jc-fabricgw-client@1.0.0: wanted: {"node":">=14","npm":">=8.0.0"} (current: {"node":"14.18.3","npm":"6.14.15"})
// npm WARN notsup Not compatible with your version of node/npm: jc-fabricgw-client@1.0.0
// npm WARN enoent ENOENT: no such file or directory, open '/home/jovyan/work/notebook/package.json'
// npm WARN notebook No description
// npm WARN notebook No repository field.
// npm WARN notebook No README data
// npm WARN notebook No license field.
//
// + jc-fabricgw-client@1.0.0
// added 95 packages from 131 contributors and audited 95 packages in 36.038s
//
// 12 packages are looking for funding
//   run `npm fund` for details
//
// found 1 high severity vulnerability
//   run `npm audit fix` to fix them, or `npm audit` for details
// 7m            ......] / postinstall: sill install printInstalled

// %% [markdown]
// #### Switch to JavaScript/Node.js Jupyter kernel and import the module

// %%
const fabric = require('jc-fabricgw-client');

// %% [markdown]
// ### Configuration
// We use a configuration file to configure our connection to the Fabric blockchain (using the Fabric Gateway service that was added in Fabric version 2.4).

// %%
const CAregisterSecret = 'jwSfmSTyalJE';
let config;
fabric.getConfig('./fabric-client-config.yaml').then((result) => {config = result;}); // promises/async: https://github.com/n-riesco/ijavascript/issues/268
// Out:
// Configuration File: ./fabric-client-config.yaml
// Promise { <pending> }

// %%
console.log(config);
// Out:
// {
//   organization: 'orgA',
//   mspId: 'MSPorgA',
//   identity: 'janssen',
//   idCertFile: './id/janssen.crt',
//   idKeyFile: './id/janssen.key',
//   caEndpoint: 'https://ca.orga.fabric.localhost:7054',
//   caTlsCertFile: '../crypto-config/fabric/peerOrganizations/orga.fabric.localhost/ca/ca.orga.fabric.localhost-cert.pem',
//   caName: 'ca.orga.fabric.localhost',
//   gatewayEndpoint: 'peer0.orga.fabric.localhost:7051',
//   gatewayTlsCertFile: '../crypto-config/fabric/peerOrganizations/orga.fabric.localhost/peers/peer0.orga.fabric.localhost/tls/ca.crt',
//   gatewayHostAlias: 'peer0.orga.fabric.localhost'
// }

// %% [markdown]
// #### User enrollment

// %%
fabric.execEnroll(config, CAregisterSecret);
// Out:
//  Enrolling...
// Promise { <pending> }
// Enrollment complete!

// %% [markdown]
// #### Configure IPFS
// Get the configuration for the local IPFS node from our Fabric blockchain. We will use the IPFS client Python module in the IPFS notebook to interact with IPFS.

// %%
fabric.execTransaction(config);
// Out:
//  Gateway exec...
// Promise { <pending> }
// Fabric Gateway error : GatewayError: 2 UNKNOWN: evaluate call to endorser returned error: chaincode response 500, The IPFS network description with ID 'net1' does not exist
